# %%
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
test = image.load_img('/users/danielcorcoran/Desktop/CNN/predictme_cartoons/28297819-funny-cat-cartoon.jpg',
                     target_size = (128,128))

# %%
test
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1123CC470>

# %%
type(test)
# Out:
# PIL.Image.Image
